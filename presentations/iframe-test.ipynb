# %%
from IPython.display import IFrame, display

# Display Wikipedia
display(IFrame('https://en.wikipedia.org', width=1000, height=400))
# Out:
#         <iframe
#             width="1000"
#             height="400"
#             src="https://en.wikipedia.org"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
